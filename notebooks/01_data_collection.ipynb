# %%
import yfinance as yf
import pandas as pd


TICKER = "AAPL"
START_DATE = "2015-01-01"
END_DATE = "2024-01-01"


# Download stock data
df = yf.download(TICKER, start=START_DATE, end=END_DATE)


# Save to CSV
df.to_csv("../data/stock_data.csv")


print(df.head())
# Out:
# /var/folders/ry/0g5rn96j6d78nr6g9yx1q6dh0000gn/T/ipykernel_8329/1931218088.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(TICKER, start=START_DATE, end=END_DATE)
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-01-02  24.237551  24.705320  23.798600  24.694235  212818400
# 2015-01-05  23.554737  24.086797  23.368517  24.006988  257142000
# 2015-01-06  23.556955  23.816334  23.195597  23.619029  263188400
# 2015-01-07  23.887281  23.987042  23.654504  23.765350  160423600
# 2015-01-08  24.805080  24.862721  24.097883  24.215381  237458000
